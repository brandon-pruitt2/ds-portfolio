# %%
# !conda install lxml

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value=2024'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,"lxml")
soup # retruns the HTML
# Out:
# <!DOCTYPE html>
# <!--
#          __  __  ____    ______                                   _________________
#    .====/ /=/ /=/ __/===/_  __/==================================/######__________/
#   .==  / / / /  \ \      / / _______ ___  ___ __ ________ __    /######__________/
#  .==  / /_/ /  __\ \    / / / __/ -_) _ \(_--/ // / __/ // /   /######__________/
# .==   \____/  /____/   /_/ /_/  \__/\_/_/___/\___/_/  \_  /   /________________/
# =====================================================__/ /===/________________/
#                                                     /___/
# --><html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# ...

# %%
soup.find_all('td', class_ = 'bc30year')[-1]
# Out:
# <td class="bc30year views-field views-field-field-bc-30year" headers="view-field-bc-30year-table-column">4.43          </td>
